# %%
from bs4 import BeautifulSoup
import requests

# %%
def getdata(url): 
    r = requests.get(url) 
    return r.text 
    
htmldata = getdata("https://sarpur.is/Heildarsafn.aspx?pageSize=192&SofnID=2,12,26,16,50,20,21,23,11,4,17,24,60,54,25,52,75,6,43,14,53,65,78,77,47,71,46,30,13,19,31,32,33,35,8,45,36,48,5,22,55,83,15,81,76,39,42,80,69,73,85,84,74,41,1,9&TegID=7,6") 
soup = BeautifulSoup(htmldata, 'html.parser') 
for item in soup.find_all('img'):
    print(item['src'])
# Out:
# /img/Sarpur_merki2_.png
# /WebResource.axd?d=bikYLXrhtGHiTroFfE_ESHazdYyApbe6YF6s3duwjaX8zLon_YCNZy631lxgG6UVMfInIUC32zh0GHo7qzt_JPVtDha4L8dC8Ne3NULP2CU1&t=637454069640000000
# /img/twitter.png
# /img/fb.png
# data:image/png;base64,...
# data:image/png;base64,...
# data:image/png;base64,...
# data:image/png;base64,...
# https://skraning.sarpur.is/Uploads/Images/2263029_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2263006_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262808_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262803_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262636_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262609_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262592_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2262581_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2261819_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2261778_tn_l.jpg
# https://skraning.sarpur.is/Uploads/Images/2261740_tn_l.jpg
# ...
